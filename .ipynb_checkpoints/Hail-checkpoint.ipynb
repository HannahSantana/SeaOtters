# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('1955-2017_hail.csv')
df.head()
# Out:
#    om    yr  mo  dy        date      time  tz  st  stf  stn ...  elon  len  \
# 0   1  1955   1  17  1955-01-17  16:39:00   3  TX   48    1 ...   0.0    0
# 1   2  1955   2   1  1955-02-01  10:30:00   3  MO   29    1 ...   0.0    0
# 2   3  1955   3   3  1955-03-03  13:02:00   3  IL   17    1 ...   0.0    0
# 3   4  1955   3   3  1955-03-03  14:00:00   3  IN   18    1 ...   0.0    0
# 4   5  1955   3   3  1955-03-03  16:00:00   3  IL   17    2 ...   0.0    0
#
#    wid  ns  sn  sg   f1  f2  f3  f4
# 0    0   0   0   0  227   0   0   0
# 1    0   0   0   0  135   0   0   0
# 2    0   0   0   0  175   0   0   0
# 3    0   0   0   0  167   0   0   0
# 4    0   0   0   0   31   0   0   0
#
# [5 rows x 28 columns]

# %%
yearly_changes = df.groupby('yr').count().reset_index()
yearly_changes.head()
# Out:
#      yr   om   mo   dy  date  time   tz   st  stf  stn ...   elon  len  wid  \
# 0  1955  344  344  344   344   344  344  344  344  344 ...    344  344  344
# 1  1956  393  393  393   393   393  393  393  393  393 ...    393  393  393
# 2  1957  467  467  467   467   467  467  467  467  467 ...    467  467  467
# 3  1958  483  483  483   483   483  483  483  483  483 ...    483  483  483
# 4  1959  527  527  527   527   527  527  527  527  527 ...    527  527  527
#
#     ns   sn   sg   f1   f2   f3   f4
# 0  344  344  344  344  344  344  344
# 1  393  393  393  393  393  393  393
# 2  467  467  467  467  467  467  467
# 3  483  483  483  483  483  483  483
# 4  527  527  527  527  527  527  527
#
# [5 rows x 28 columns]

# %%
fig = plt.figure()
plt.figure(figsize=(20, 8))
sns.regplot(yearly_changes['yr'], yearly_changes['time'])

plt.scatter(yearly_changes.yr, yearly_changes.time)
plt.xlabel('1955-2018', fontsize = 15)
plt.ylabel('Number of Hail Storms', fontsize = 15)
plt.title('Hail Storms since 1955', fontsize = 15)

plt.savefig('hail_storms_1955.png')

# %%
mag = df.groupby('yr')['mag'].mean().reset_index()

# %%
fig = plt.figure()
plt.figure(figsize=(20, 8))
sns.regplot(mag['yr'], mag['mag'])

plt.scatter(mag.yr, mag.mag)
plt.xlabel('1955-2018', fontsize = 15)
plt.ylabel('Average Diameter of Hail in inches', fontsize = 15)
plt.title('Average Diameter of Hail', fontsize = 15)

plt.savefig('avg_diameter_hail.png')

# %%
maximum = df.groupby('yr')['mag'].max().reset_index()

# %%
fig = plt.figure()
plt.figure(figsize=(20, 8))
sns.regplot(maximum['yr'], maximum['mag'])

plt.scatter(maximum.yr, maximum.mag)
plt.xlabel('1955-2018', fontsize = 15)
plt.ylabel('Maximum Diameter of Hail in inches', fontsize = 15)
plt.title('Maximum Diameter of Hail', fontsize = 15)

plt.savefig('max_diameter_of_hail.png')
